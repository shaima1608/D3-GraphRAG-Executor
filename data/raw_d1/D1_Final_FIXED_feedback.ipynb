# %% [markdown]
# ## Mount Google Drive
#
# This cell connects the notebook to Google Drive so the project files can be accessed directly inside Google Colab. It uses the Google Colab drive mounting function to link the notebook with the user’s Drive storage. This allows the notebook to load the dataset folder, PDF files, Excel evaluation file, and save outputs such as the final run card and evaluation results.

# %%
#mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Install Required Packages
#
# This cell installs all external Python packages required for the project. It uses pip installation commands to download retrieval, machine learning, PDF processing, AutoML, and online learning libraries that may not already exist in the Colab environment. The installed packages support tasks such as BM25 retrieval, TF-IDF vectorization, Optuna optimization, River online learning, Excel reading, and PDF text extraction.

# %%
# !pip install pandas
# !pip install pandas PyPDF2 scikit-learn
# !pip install pandas PyPDF2 scikit-learn openpyxl optuna rank-bm25 river
# !pip install optuna rank-bm25 river
# !pip install openpyxl
# !pip install river
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.12/dist-packages (3.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.12/dist-packages (3.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.8.0)
# Requirement already satisfied: rank-bm25 in /usr/local/lib/python3.12/dist-packages (0.2.2)
# Requirement already satisfied: river in /usr/local/lib/python3.12/dist-packages (0.24.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.11)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.8.0)
# Requirement already satisfied: rank-bm25 in /usr/local/lib/python3.12/dist-packages (0.2.2)
# Requirement already satisfied: river in /usr/local/lib/python3.12/dist-packages (0.24.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: scipy<2,>=1.16 in /usr/local/lib/python3.12/dist-packages (from river) (1.16.3)
# Requirement already satisfied: pandas<3,>=2.2 in /usr/local/lib/python3.12/dist-packages (from river) (2.2.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.11)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.2->river) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.2->river) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.2->river) (2026.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=2.2->river) (1.17.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: river in /usr/local/lib/python3.12/dist-packages (0.24.2)
# Requirement already satisfied: scipy<2,>=1.16 in /usr/local/lib/python3.12/dist-packages (from river) (1.16.3)
# Requirement already satisfied: pandas<3,>=2.2 in /usr/local/lib/python3.12/dist-packages (from river) (2.2.2)
# Requirement already satisfied: numpy<3,>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from river) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.2->river) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.2->river) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.2->river) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=2.2->river) (1.17.0)

# %% [markdown]
# ## Import Libraries
#
# This cell imports all libraries used throughout the notebook. The imported modules provide support for data handling, PDF reading, retrieval models, machine learning evaluation, plotting, timing, online learning, and JSON export. The cell includes packages such as pandas, NumPy, scikit-learn, matplotlib, Optuna, River, and utility libraries required for the retrieval pipeline.

# %%
import os
import time
import json
import optuna
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PyPDF2 import PdfReader
from rank_bm25 import BM25Okapi

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import ndcg_score
from sklearn.metrics.pairwise import cosine_similarity

from river import linear_model, preprocessing, metrics
from river.drift import ADWIN

# %% [markdown]
# ## Set Dataset Paths
#
# This cell defines the file paths used throughout the project. It stores the Google Drive locations for the PDF dataset folder, the Excel file containing the evaluation questions, and output locations for generated files. Using variables for file paths makes the notebook easier to manage and allows later cells to reuse the same dataset paths consistently.

# %%
FOLDER_PATH = "/content/drive/MyDrive/AItopics"
EXCEL_PATH = FOLDER_PATH + "/question.xlsx"

# %% [markdown]
# ## List Dataset Folder Files
#
# This cell checks the contents of the dataset folder to verify that all required files are available. It reads and prints the names of the files inside the Google Drive dataset directory so the user can confirm that the PDFs and Excel question file exist before running the retrieval pipeline.

# %%
for f in os.listdir("/content/drive/MyDrive/AItopics"):
    print(f)
# Out:
# 9780203802878_previewpdf.pdf
# article-p35.pdf
# s44163-022-00022-8.pdf
# Informe-AI-Now.pdf
# Complexity - 2021 - Zhai - A Review of Artificial Intelligence  AI  in Education from 2010 to 2020.pdf
# bjd0423.pdf
# AD1099286.pdf
# ai_drives_final.pdf
# CS-TR-3290.pdf
# Artificial Intelligence (AI) Ethics_ Ethics of AI and Ethical AI.pdf
# nature20230927_AI_and_science.pdf
# 978-3-030-69978-9_4.pdf
# 1412.6980v9.pdf
# ioffe15.pdf
# NIPS-2012-imagenet-classification-with-deep-convolutional-neural-networks-Paper.pdf
# 1312.5602v1.pdf
# A_1010933404324.pdf
# srivastava14a.pdf
# 2939672.2939785.pdf
# 1511.06434v2.pdf
# NIPS-2017-attention-is-all-you-need-Paper.pdf
# N19-1423.pdf
# NeurIPS-2020-language-models-are-few-shot-learners-Paper.pdf
# 2203.02155v1.pdf
# 2302.13971v1.pdf
# 2303.08774v6.pdf
# 2303.18223v19.pdf
# 1603.09320v4.pdf
# 1708.05031v2.pdf
# 1606.07792v1.pdf
# 45530.pdf
# Recommender-Systems-[Netflix].pdf
# MSR-TR-2010-82.pdf
# MSR-TR-2010-82 (1).pdf
# Brin98Anatomy.pdf
# bergstra12a.pdf
# 1908.00709v6.pdf
# 1802.03268v2.pdf
# 1806.09055v2.pdf
# OLsurvey.pdf
# mapreduce-osdi04.pdf
# Zaharia.pdf
# 15-237.pdf
# osdi16-abadi.pdf
# s41746-021-00486-5.pdf
# 1604.07316v1.pdf
# 1910.07738v2.pdf
# NIPS-2015-faster-r-cnn-towards-real-time-object-detection-with-region-proposal-networks-Paper.pdf
# Redmon_You_Only_Look_CVPR_2016_paper.pdf
# 1301.3781v3.pdf
# D14-1162.pdf
# 1907.11692v1.pdf
# 1909.11942v6.pdf
# 20-074.pdf
# 2402.08877v2.pdf
# 2309.12288v4.pdf
# 2307.03172v3.pdf
# 2305.10601v2.pdf
# 2201.11903v6.pdf
# 2303.18223v19 (1).pdf
# 1606.06565v2.pdf
# 1802.07228v2.pdf
# 1602.04938v3.pdf
# 1910.10045v2.pdf
# 1908.09635v3.pdf
# 1901.02062v1.pdf
# irbookonlinereading.pdf
# 582415.582418.pdf
# p1792-Akidau.pdf
# 41378.pdf
# 2206.08788v1.pdf
# 1802.05799v3.pdf
# osdi18-moritz.pdf
# NIPS-2012-on-triangular-versus-edge-representations-towards-scalable-modeling-of-networks-Paper.pdf
# 1709.05067v1.pdf
# 20-1380.pdf
# 2208.08954v1.pdf
# 1902.05978v2.pdf
# 1911.06270v2.pdf
# 2210.07658v2.pdf
# 2005.04353v1.pdf
# 1808.00177v5.pdf
# 2307.15818v1.pdf
# 2005.06239v2.pdf
# 1711.09883v2.pdf
# 2204.02311v5.pdf
# 2204.02311v5 (1).pdf
# 2203.15556v1.pdf
# 2212.08073v1.pdf
# 2306.05685v4.pdf
# 2310.06825v1.pdf
# 2306.01116v1.pdf
# 2005.11401v4.pdf
# 2310.11511v1.pdf
# 2310.01352v4.pdf
# 2204.14198v2.pdf
# 2301.12597v3.pdf
# 2305.05665v2.pdf
# 1609.02907v4.pdf
# 1710.10903v3.pdf
# 1812.08434v6.pdf
# 2205.11487v1.pdf
# 2204.06125v1.pdf
# 2112.10752v2.pdf
# 2006.11239v2.pdf
# 1602.05629v4.pdf
# 2302.04761v1.pdf
# 2210.03629v3.pdf
# 1908.07873v1.pdf
# question.xlsx

# %% [markdown]
# ## Load Questions Excel File
#
# This cell loads the Excel file containing the evaluation questions and their correct PDF answers. It reads the spreadsheet into a pandas DataFrame and validates the important columns used later during retrieval evaluation. The loaded dataset becomes the main query set used to test the retrieval system.

# %%
df = pd.read_excel(EXCEL_PATH, engine="openpyxl")
df.columns = df.columns.str.strip().str.replace(" ", "_")
df.head()
# Out:
#                                             Question       Correct_PDF  \
# 0  What is the main AI-related objective of Effic...   1301.3781v3.pdf
# 1  What is the main AI-related objective of Playi...   1312.5602v1.pdf
# 2  What is the main AI-related objective of ADAM:...   1412.6980v9.pdf
# 3  What is the main AI-related objective of MLlib...        15-237.pdf
# 4  What is the main AI-related objective of All e...  1508.07906v2.pdf
#
#                                         Short_Answer  \
# 0  Two novel model architectures for computing co...
# 1  The first deep learning model to successfully ...
# 2  Adam, an algorithm for first-order gradient-ba...
# 3  Apache Spark is a popular open-source platform...
# 4  All electrical manipulation of magnetization d...
#
#                         Actual_PDF_Title_From_Inside
# 0  Efficient Estimation of Word Representations i...
# 1  Playing Atari with Deep Reinforcement Learning...
# 2  ADAM: A METHOD FOR STOCHASTIC OPTIMIZATION Die...
# 3  MLlib: Machine Learning in Apache Spark Xiangr...
# 4  All electrical manipulation of magnetization d...

# %% [markdown]
# ## Extract PDF Title and Abstract Only
#
# This cell extracts only the title and abstract text from each PDF instead of using the full document content. The extraction function reads the first pages of every PDF, searches for the abstract section, and stops before later sections such as the introduction. This approach reduces unnecessary information and creates a cleaner retrieval dataset focused on the main research summaries.

# %%
import re


def extract_title_abstract(text, filename):
    text = text or ""
    text = re.sub(r"\s+", " ", text).strip()

    if not text:
        return filename.replace(".pdf", "")

    abstract_match = re.search(r"\babstract\b", text, flags=re.IGNORECASE)

    if abstract_match:
        title = text[:abstract_match.start()].strip()
        after_abstract = text[abstract_match.end():].strip()

        end_match = re.search(
            r"\b(keywords|index terms|introduction|1\.\s*introduction|i\.\s*introduction)\b",
            after_abstract,
            flags=re.IGNORECASE
        )

        if end_match:
            abstract = after_abstract[:end_match.start()].strip()
        else:
            abstract = after_abstract[:2500].strip()

        title = title[:500].strip()
        return (title + "\n" + abstract).strip()

    # Fallback if no Abstract heading is found: keep only the first part, not full PDF
    return text[:1200].strip()


pdf_texts = {}
pdf_pages = {}

for file in os.listdir(FOLDER_PATH):
    if file.endswith(".pdf"):
        path = os.path.join(FOLDER_PATH, file)

        full_text = ""
        pages = []

        try:
            reader = PdfReader(path)

            for page_num, page in enumerate(reader.pages, start=1):
                page_text = page.extract_text() or ""
                full_text += page_text + "\n"

            title_abstract_text = extract_title_abstract(full_text, file)

            pages.append({
                "page": 1,
                "text": title_abstract_text
            })

        except Exception as e:
            print("Error reading:", file, e)
            title_abstract_text = ""
            pages = []

        pdf_texts[file] = title_abstract_text
        pdf_pages[file] = pages

print("Loaded PDFs:", len(pdf_texts))
print("Extraction mode: title + abstract only")
# Out:
# WARNING:PyPDF2.generic._base:FloatObject (b'0.00-34120734') invalid; use 0.0 instead
# Loaded PDFs: 109
# Extraction mode: title + abstract only

# %% [markdown]
# ## Create Document Lists
#
# This cell processes all PDFs in the dataset folder and builds the main document collection used for retrieval. It applies the title and abstract extraction function to every PDF file and stores the extracted text together with the corresponding PDF filename. The result is a structured dataset of documents ready for indexing and retrieval.

# %%
doc_names = list(pdf_texts.keys())
documents = list(pdf_texts.values())

print("Documents ready:", len(documents))
# Out:
# Documents ready: 109

# %% [markdown]
# ## Create PDF Name Map
#
# This cell standardizes and maps PDF filenames to improve evaluation matching. It cleans file names and creates mappings between simplified names and original filenames so that retrieved results can be compared correctly against the expected PDF answers in the evaluation dataset.

# %%
name_map = {}

for pdf in os.listdir(FOLDER_PATH):
    if pdf.endswith(".pdf"):
        clean_name = pdf.replace(".pdf", "")
        name_map[clean_name] = pdf

# %% [markdown]
# ##  Create Page-Based Chunks
#
# This cell splits the extracted title and abstract text into smaller searchable chunks. Chunking helps the retrieval system search more effectively because retrieval models work better with smaller text units instead of very long document strings. The cell also stores metadata such as source PDF names and chunk information.

# %%
def make_page_chunks(pages, chunk_size=1000, overlap=200):
    chunks = []
    page_numbers = []

    for page in pages:
        text = page["text"]
        page_num = page["page"]

        start = 0
        while start < len(text):
            end = start + chunk_size
            chunks.append(text[start:end])
            page_numbers.append(page_num)
            start += chunk_size - overlap

    return chunks, page_numbers


chunk_texts = []
chunk_sources = []
chunk_pages = []

for pdf_name, pages in pdf_pages.items():
    chunks, pages_list = make_page_chunks(pages)

    for chunk, page_num in zip(chunks, pages_list):
        chunk_texts.append(chunk)
        chunk_sources.append(pdf_name)
        chunk_pages.append(page_num)

print("Total chunks:", len(chunk_texts))
# Out:
# Total chunks: 471

# %% [markdown]
# ## Baseline TF-IDF Evaluation
#
# This cell builds the baseline retrieval system using TF-IDF vectorization and cosine similarity retrieval. It converts document text into numerical vectors and retrieves the top matching PDFs for each query. The system is then evaluated using Recall@5, NDCG@5, and p95 latency to measure retrieval quality and speed before AutoML optimization.

# %%
baseline_vectorizer = TfidfVectorizer(stop_words="english")
baseline_vectors = baseline_vectorizer.fit_transform(documents)

def baseline_search_top5(query):
    q_vec = baseline_vectorizer.transform([query])
    scores = cosine_similarity(q_vec, baseline_vectors).flatten()
    top_idx = scores.argsort()[-5:][::-1]

    top5 = [doc_names[i] for i in top_idx]
    top5_scores = [float(scores[i]) for i in top_idx]

    while len(top5) < 5:
        top5.append("NO_RESULT")

    while len(top5_scores) < 5:
        top5_scores.append(0.0)

    return top5, top5_scores


baseline_correct = 0
baseline_ndcg_scores = []
baseline_times = []

for _, row in df.iterrows():
    q = row["Question"]
    true_file = row["Correct_PDF"]

    start_time = time.time()

    top5, scores = baseline_search_top5(q)

    end_time = time.time()
    baseline_times.append(end_time - start_time)

    relevance = [1 if pdf == true_file else 0 for pdf in top5]

    if true_file in top5:
        baseline_correct += 1

    baseline_ndcg_scores.append(ndcg_score([relevance], [scores]))

baseline_recall = baseline_correct / len(df)
baseline_ndcg = np.mean(baseline_ndcg_scores)
baseline_p95_latency = np.percentile(baseline_times, 95)

print("Baseline Recall@5:", round(baseline_recall, 4))
print("Baseline NDCG@5:", round(baseline_ndcg, 4))
print("Baseline p95 latency:", round(baseline_p95_latency, 6), "seconds")
# Out:
# Baseline Recall@5: 0.9667
# Baseline NDCG@5: 0.9294
# Baseline p95 latency: 0.001481 seconds

# %% [markdown]
# ## Build BM25 Index
#
# This cell creates the BM25 lexical retrieval index used in the hybrid retrieval system. It tokenizes document chunks into words and builds the BM25 scoring model so queries can retrieve documents using keyword-based similarity. BM25 provides strong lexical retrieval that complements the semantic retrieval model later in the pipeline.

# %%
tokenized_chunks = [c.lower().split() for c in chunk_texts]
bm25 = BM25Okapi(tokenized_chunks)

print("BM25 ready")
# Out:
# BM25 ready

# %% [markdown]
# ## Run Optuna AutoML Search
#
# This cell performs AutoML optimization using Optuna to search for the best retrieval configuration. Multiple trials are executed using different combinations of hyperparameters such as k values, similarity metrics, SVD dimensions, normalization settings, TF-IDF feature limits, and hybrid weights. The optimization objective balances retrieval quality and latency.

# %%
def evaluate_knn_config(trial):

    k = trial.suggest_categorical("k", [5, 10, 20, 50])
    metric = trial.suggest_categorical("metric", ["cosine", "euclidean"])
    svd_dim = trial.suggest_categorical("svd_dim", [50, 100, 200])
    normalize = trial.suggest_categorical("normalize", [True, False])
    max_features = trial.suggest_categorical("max_features", [3000, 5000, 10000])
    hybrid_weight = trial.suggest_float("hybrid_weight", 0.2, 0.8)

    vectorizer = TfidfVectorizer(
        stop_words="english",
        ngram_range=(1, 2),
        max_features=max_features
    )

    X = vectorizer.fit_transform(chunk_texts)

    svd = TruncatedSVD(
        n_components=min(svd_dim, X.shape[1] - 1),
        random_state=42
    )

    X_svd = svd.fit_transform(X)

    if normalize:
        normalizer = Normalizer()
        X_svd = normalizer.fit_transform(X_svd)
    else:
        normalizer = None

    knn = NearestNeighbors(
        n_neighbors=min(k, len(chunk_texts)),
        metric=metric
    )

    knn.fit(X_svd)

    correct = 0
    ndcg_scores = []
    query_times = []

    for _, row in df.iterrows():

        query = row["Question"]
        true_file = row["Correct_PDF"]

        start_time = time.time()

        q_vec = vectorizer.transform([query])
        q_svd = svd.transform(q_vec)

        if normalizer is not None:
            q_svd = normalizer.transform(q_svd)

        distances, indices = knn.kneighbors(q_svd)

        knn_scores = 1 / (1 + distances[0])
        bm25_scores = np.array(bm25.get_scores(query.lower().split()))

        if bm25_scores.max() > 0:
            bm25_scores = bm25_scores / bm25_scores.max()

        candidate_scores = {}

        for knn_score, idx in zip(knn_scores, indices[0]):

            pdf_name = chunk_sources[idx]
            bm25_score = bm25_scores[idx]

            final_score = (hybrid_weight * knn_score) + ((1 - hybrid_weight) * bm25_score)

            if pdf_name not in candidate_scores or final_score > candidate_scores[pdf_name]:
                candidate_scores[pdf_name] = final_score

        ranked_results = sorted(
            candidate_scores.items(),
            key=lambda x: x[1],
            reverse=True
        )

        top5 = [pdf for pdf, score in ranked_results[:5]]
        scores = [score for pdf, score in ranked_results[:5]]

        while len(top5) < 5:
            top5.append("NO_RESULT")

        while len(scores) < 5:
            scores.append(0)

        relevance = [1 if pdf == true_file else 0 for pdf in top5]

        if true_file in top5:
            correct += 1

        ndcg_scores.append(ndcg_score([relevance], [scores]))
        query_times.append(time.time() - start_time)

    recall = correct / len(df)
    mean_ndcg = np.mean(ndcg_scores)
    p95_latency = np.percentile(query_times, 95)

    objective_score = (0.5 * recall) + (0.5 * mean_ndcg) - (0.05 * p95_latency)

    trial.set_user_attr("recall_at_5", recall)
    trial.set_user_attr("ndcg_at_5", mean_ndcg)
    trial.set_user_attr("p95_latency", p95_latency)

    return objective_score


samplers = {
    "TPE": optuna.samplers.TPESampler(seed=42),
    "Random Search": optuna.samplers.RandomSampler(seed=42)
}

sampler_results = {}

for optimizer_name, sampler in samplers.items():

    print(f"\nRunning {optimizer_name} optimizer...")

    temp_study = optuna.create_study(
        direction="maximize",
        sampler=sampler
    )

    temp_study.optimize(evaluate_knn_config, n_trials=30)

    sampler_results[optimizer_name] = {
        "best_objective": temp_study.best_value,
        "best_params": temp_study.best_params,
        "recall_at_5": temp_study.best_trial.user_attrs["recall_at_5"],
        "ndcg_at_5": temp_study.best_trial.user_attrs["ndcg_at_5"],
        "p95_latency": temp_study.best_trial.user_attrs["p95_latency"]
    }

sampler_results_df = pd.DataFrame(sampler_results).T
display(sampler_results_df)

best_sampler_name = sampler_results_df["best_objective"].idxmax()

print("\nBest optimizer:", best_sampler_name)

study = optuna.create_study(
    direction="maximize",
    sampler=samplers[best_sampler_name]
)

study.optimize(evaluate_knn_config, n_trials=30)

best = study.best_params

print("\nBest objective score:", round(study.best_value, 4))
print("Best parameters:", best)
print("Best trial Recall@5:", round(study.best_trial.user_attrs["recall_at_5"], 4))
print("Best trial NDCG@5:", round(study.best_trial.user_attrs["ndcg_at_5"], 4))
print("Best trial p95 latency:", round(study.best_trial.user_attrs["p95_latency"], 6))
# Out:
# [I 2026-05-23 14:29:49,184] A new study created in memory with name: no-name-0ab17902-3073-4dce-b5f5-aa69a38cc428
# Running TPE optimizer...
# [I 2026-05-23 14:29:50,200] Trial 0 finished with value: 0.925585802073611 and parameters: {'k': 10, 'metric': 'cosine', 'svd_dim': 100, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.3090949803242604}. Best is trial 0 with value: 0.925585802073611.
# [I 2026-05-23 14:29:51,960] Trial 1 finished with value: 0.9342225105105808 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 200, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.22787024763199865}. Best is trial 1 with value: 0.9342225105105808.
# [I 2026-05-23 14:29:54,280] Trial 2 finished with value: 0.9489756155549458 and parameters: {'k': 50, 'metric': 'cosine', 'svd_dim': 200, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.3552679889600102}. Best is trial 2 with value: 0.9489756155549458.
# [I 2026-05-23 14:29:55,734] Trial 3 finished with value: 0.6399253953378673 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 5000, 'hybrid_weight': 0.39519819845795867}. Best is trial 2 with value: 0.9489756155549458.
# [I 2026-05-23 14:29:57,852] Trial 4 finished with value: 0.9591782476769211 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.6241144063085704}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:29:58,758] Trial 5 finished with value: 0.6451372215195912 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.4833289550971696}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:29:59,715] Trial 6 finished with value: 0.9170254680591764 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 50, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.7445398843556559}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:00,898] Trial 7 finished with value: 0.8070707610004475 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.5236053451493905}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:02,085] Trial 8 finished with value: 0.9427266799003812 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.7657458223475115}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:03,121] Trial 9 finished with value: 0.9341795045672824 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.3671878785419669}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:03,999] Trial 10 finished with value: 0.9518571265106351 and parameters: {'k': 50, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.6399190066427125}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:04,879] Trial 11 finished with value: 0.9518843992118985 and parameters: {'k': 50, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.6422818792009711}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:05,746] Trial 12 finished with value: 0.9518670894270093 and parameters: {'k': 50, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.6227932553167616}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:06,613] Trial 13 finished with value: 0.8810503620496324 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.6446341508693647}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:08,041] Trial 14 finished with value: 0.9540620774566104 and parameters: {'k': 50, 'metric': 'euclidean', 'svd_dim': 200, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.5507782931684838}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:11,108] Trial 15 finished with value: 0.9540798223554066 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 200, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.5219146802612783}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:13,486] Trial 16 finished with value: 0.9538376951966019 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 200, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.44866970800862666}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:15,314] Trial 17 finished with value: 0.9541792387305668 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 200, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.5589514549976993}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:16,523] Trial 18 finished with value: 0.9570385400811643 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.7060524970097224}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:17,751] Trial 19 finished with value: 0.955993416964107 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.7157899251173309}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:18,988] Trial 20 finished with value: 0.9388896257756095 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.7021436182234757}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:20,231] Trial 21 finished with value: 0.9560425848355822 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.7966460588888731}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:21,447] Trial 22 finished with value: 0.9560125053515963 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.7900981363972192}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:22,900] Trial 23 finished with value: 0.9568512485782117 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.6899211608063223}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:25,382] Trial 24 finished with value: 0.9568826792994947 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.687826891841176}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:27,209] Trial 25 finished with value: 0.9375775043434225 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.5845122662507176}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:28,448] Trial 26 finished with value: 0.9569959930936307 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.6757968797215829}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:29,678] Trial 27 finished with value: 0.9581173217077367 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.6048418194259998}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:30,911] Trial 28 finished with value: 0.9401548597777835 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.5821065637807025}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:31,875] Trial 29 finished with value: 0.9245759812771591 and parameters: {'k': 10, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.600850325895706}. Best is trial 4 with value: 0.9591782476769211.
# [I 2026-05-23 14:30:31,876] A new study created in memory with name: no-name-4062616e-f925-42a7-8105-ba56acc6e601
# Running Random Search optimizer...
# [I 2026-05-23 14:30:32,872] Trial 0 finished with value: 0.9256007568789851 and parameters: {'k': 10, 'metric': 'cosine', 'svd_dim': 100, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.3090949803242604}. Best is trial 0 with value: 0.9256007568789851.
# [I 2026-05-23 14:30:34,556] Trial 1 finished with value: 0.934228936487334 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 200, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.22787024763199865}. Best is trial 1 with value: 0.934228936487334.
# [I 2026-05-23 14:30:36,448] Trial 2 finished with value: 0.9491581476270131 and parameters: {'k': 50, 'metric': 'cosine', 'svd_dim': 200, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.3552679889600102}. Best is trial 2 with value: 0.9491581476270131.
# [I 2026-05-23 14:30:37,696] Trial 3 finished with value: 0.639887694207954 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 5000, 'hybrid_weight': 0.39519819845795867}. Best is trial 2 with value: 0.9491581476270131.
# [I 2026-05-23 14:30:39,960] Trial 4 finished with value: 0.9592423554526092 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.6241144063085704}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:41,587] Trial 5 finished with value: 0.6450687173053045 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.4833289550971696}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:42,501] Trial 6 finished with value: 0.9172693070846738 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 50, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.7445398843556559}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:43,653] Trial 7 finished with value: 0.8072118314855626 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.5236053451493905}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:44,867] Trial 8 finished with value: 0.9426970087082119 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.7657458223475115}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:45,896] Trial 9 finished with value: 0.9341588920890262 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.3671878785419669}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:46,968] Trial 10 finished with value: 0.938493073539431 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 100, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.254173862032645}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:48,142] Trial 11 finished with value: 0.9310544974198869 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.282512566487596}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:49,047] Trial 12 finished with value: 0.911893140968451 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.4034178746292204}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:50,433] Trial 13 finished with value: 0.9538083238157959 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 200, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.2964848308504992}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:51,427] Trial 14 finished with value: 0.9259983510043543 and parameters: {'k': 10, 'metric': 'cosine', 'svd_dim': 100, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.3591214206090353}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:53,628] Trial 15 finished with value: 0.7014096109938207 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.3062664076442294}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:56,378] Trial 16 finished with value: 0.946096435321751 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.3016956480116555}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:57,265] Trial 17 finished with value: 0.9060179285743803 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.37615510655869605}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:58,231] Trial 18 finished with value: 0.9540594149171283 and parameters: {'k': 50, 'metric': 'cosine', 'svd_dim': 50, 'normalize': False, 'max_features': 5000, 'hybrid_weight': 0.5469680845977045}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:30:59,208] Trial 19 finished with value: 0.9340898140093524 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 100, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.2512084789962608}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:31:00,893] Trial 20 finished with value: 0.9425699093479882 and parameters: {'k': 50, 'metric': 'euclidean', 'svd_dim': 200, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.7015880723073236}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:31:01,752] Trial 21 finished with value: 0.8823233595567883 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.3486385937006945}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:31:02,616] Trial 22 finished with value: 0.8728630315595695 and parameters: {'k': 10, 'metric': 'cosine', 'svd_dim': 50, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.4391028406384241}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:31:03,609] Trial 23 finished with value: 0.9061531312598613 and parameters: {'k': 10, 'metric': 'cosine', 'svd_dim': 50, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.5452845067255274}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:31:04,566] Trial 24 finished with value: 0.9057681029857039 and parameters: {'k': 10, 'metric': 'cosine', 'svd_dim': 50, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.24271318907613743}. Best is trial 4 with value: 0.9592423554526092.
# [I 2026-05-23 14:31:06,486] Trial 25 finished with value: 0.9592584976885545 and parameters: {'k': 10, 'metric': 'cosine', 'svd_dim': 200, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.6841008435603585}. Best is trial 25 with value: 0.9592584976885545.
# [I 2026-05-23 14:31:07,724] Trial 26 finished with value: 0.8437889386294227 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.3920297606183671}. Best is trial 25 with value: 0.9592584976885545.
# [I 2026-05-23 14:31:09,857] Trial 27 finished with value: 0.953804901317093 and parameters: {'k': 50, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.651424717662608}. Best is trial 25 with value: 0.9592584976885545.
# [I 2026-05-23 14:31:11,138] Trial 28 finished with value: 0.6210545677171244 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.25046408366899847}. Best is trial 25 with value: 0.9592584976885545.
# [I 2026-05-23 14:31:11,938] Trial 29 finished with value: 0.7466196302165305 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.2501004300192013}. Best is trial 25 with value: 0.9592584976885545.
#               best_objective  \
# TPE                 0.959178
# Random Search       0.959258
#
#                                                      best_params recall_at_5  \
# TPE            {'k': 20, 'metric': 'euclidean', 'svd_dim': 10...    0.966667
# Random Search  {'k': 10, 'metric': 'cosine', 'svd_dim': 200, ...    0.966667
#
#               ndcg_at_5 p95_latency
# TPE            0.952737    0.010473
# Random Search  0.953029     0.01179
# [I 2026-05-23 14:31:11,955] A new study created in memory with name: no-name-40450251-4ff0-4c6f-9cb6-65bb8ef8f8a6
# Best optimizer: Random Search
# [I 2026-05-23 14:31:12,989] Trial 0 finished with value: 0.9555426449383589 and parameters: {'k': 50, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.7773035290847252}. Best is trial 0 with value: 0.9555426449383589.
# [I 2026-05-23 14:31:14,025] Trial 1 finished with value: 0.9392642345295669 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 50, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.5138587065020894}. Best is trial 0 with value: 0.9555426449383589.
# [I 2026-05-23 14:31:15,090] Trial 2 finished with value: 0.9261933900250819 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 200, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.47821904296398937}. Best is trial 0 with value: 0.9555426449383589.
# [I 2026-05-23 14:31:16,958] Trial 3 finished with value: 0.9533550160691092 and parameters: {'k': 50, 'metric': 'cosine', 'svd_dim': 200, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.635431705033016}. Best is trial 0 with value: 0.9555426449383589.
# [I 2026-05-23 14:31:18,234] Trial 4 finished with value: 0.9581047349948995 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 200, 'normalize': False, 'max_features': 5000, 'hybrid_weight': 0.7029972228266828}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:19,121] Trial 5 finished with value: 0.8439400143502098 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 50, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.277495649090897}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:20,151] Trial 6 finished with value: 0.9104323249139331 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 100, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.7259921615950071}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:21,126] Trial 7 finished with value: 0.8317124145739268 and parameters: {'k': 50, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.40895328021398025}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:23,696] Trial 8 finished with value: 0.8084489940842331 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.5800405125900355}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:25,753] Trial 9 finished with value: 0.843794725644384 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 50, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.22452116975988734}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:26,878] Trial 10 finished with value: 0.9273535535554924 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 200, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.7241471744640664}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:28,264] Trial 11 finished with value: 0.9505205362119219 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 200, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.3514621666064125}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:29,204] Trial 12 finished with value: 0.9057651316941618 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.2718572790915508}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:31,075] Trial 13 finished with value: 0.94455347856402 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 200, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.5424669828013472}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:31,916] Trial 14 finished with value: 0.8725899174351466 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.44623809619379695}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:33,772] Trial 15 finished with value: 0.9437927396176201 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 200, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.312226249134514}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:34,730] Trial 16 finished with value: 0.8472002554959039 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 5000, 'hybrid_weight': 0.23802498228366065}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:35,563] Trial 17 finished with value: 0.5366725648054108 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': False, 'max_features': 5000, 'hybrid_weight': 0.6385204851221866}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:37,394] Trial 18 finished with value: 0.6211394030080332 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.41529829047410155}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:39,921] Trial 19 finished with value: 0.5664943022339002 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.5745427975483953}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:41,893] Trial 20 finished with value: 0.9521547648065618 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 200, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.22011946084146763}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:42,839] Trial 21 finished with value: 0.9114626242497874 and parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 50, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.5846885797311785}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:43,808] Trial 22 finished with value: 0.8866593839292676 and parameters: {'k': 5, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.21086611029250432}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:44,939] Trial 23 finished with value: 0.9407072073043226 and parameters: {'k': 10, 'metric': 'cosine', 'svd_dim': 200, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.2679428275044532}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:45,943] Trial 24 finished with value: 0.8866466970806272 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 50, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.5224373617627538}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:46,829] Trial 25 finished with value: 0.8439703143713814 and parameters: {'k': 5, 'metric': 'cosine', 'svd_dim': 50, 'normalize': True, 'max_features': 3000, 'hybrid_weight': 0.5793585727517183}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:48,010] Trial 26 finished with value: 0.9493066853820256 and parameters: {'k': 50, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': True, 'max_features': 10000, 'hybrid_weight': 0.3230837842892043}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:49,147] Trial 27 finished with value: 0.8600275837967511 and parameters: {'k': 50, 'metric': 'euclidean', 'svd_dim': 100, 'normalize': False, 'max_features': 10000, 'hybrid_weight': 0.7676692772801796}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:49,933] Trial 28 finished with value: 0.7466163099601725 and parameters: {'k': 20, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': False, 'max_features': 3000, 'hybrid_weight': 0.6799496512239137}. Best is trial 4 with value: 0.9581047349948995.
# [I 2026-05-23 14:31:51,095] Trial 29 finished with value: 0.9057332204320997 and parameters: {'k': 10, 'metric': 'euclidean', 'svd_dim': 50, 'normalize': True, 'max_features': 5000, 'hybrid_weight': 0.2513051185126809}. Best is trial 4 with value: 0.9581047349948995.
# Best objective score: 0.9581
# Best parameters: {'k': 20, 'metric': 'cosine', 'svd_dim': 200, 'normalize': False, 'max_features': 5000, 'hybrid_weight': 0.7029972228266828}
# Best trial Recall@5: 0.9667
# Best trial NDCG@5: 0.9503
# Best trial p95 latency: 0.007339

# %% [markdown]
# ##  Build Final Optimized Retriever
#
# This cell builds the final optimized retriever using the best hyperparameters discovered by Optuna. It creates the final TF-IDF vectorizer, applies dimensionality reduction if required, optionally normalizes vectors, and trains the final kNN retrieval model using the winning AutoML configuration.

# %%
best = study.best_params

final_vectorizer = TfidfVectorizer(
    stop_words="english",
    ngram_range=(1, 2),
    max_features=best["max_features"]
)

X = final_vectorizer.fit_transform(chunk_texts)

final_svd = TruncatedSVD(
    n_components=min(best["svd_dim"], X.shape[1] - 1),
    random_state=42
)

X_svd = final_svd.fit_transform(X)

if best["normalize"]:
    final_normalizer = Normalizer()
    X_svd = final_normalizer.fit_transform(X_svd)
else:
    final_normalizer = None

final_knn = NearestNeighbors(
    n_neighbors=min(best["k"], len(chunk_texts)),
    metric=best["metric"]
)

final_knn.fit(X_svd)

print("Final AutoML model ready")
print("Best k:", best["k"])
print("Best metric:", best["metric"])
print("Best SVD dimension:", best["svd_dim"])
print("Best normalization:", best["normalize"])
print("Best max features:", best["max_features"])
print("Best hybrid weight:", round(best["hybrid_weight"], 4))
# Out:
# Final AutoML model ready
# Best k: 20
# Best metric: cosine
# Best SVD dimension: 200
# Best normalization: False
# Best max features: 5000
# Best hybrid weight: 0.703

# %% [markdown]
# ## Define Final Hybrid Retrieval Function
#
# This cell defines the final hybrid retrieval function used during evaluation. The function retrieves candidates from both the optimized kNN retriever and the BM25 retriever, combines their scores using the optimized hybrid weight, removes duplicates, and returns the top ranked PDF results for each query.

# %%
def knn_search_top5(query, hybrid_weight=None):

    if hybrid_weight is None:
        hybrid_weight = best["hybrid_weight"]

    hybrid_weight = float(np.clip(hybrid_weight, 0.0, 1.0))

    q_vec = final_vectorizer.transform([query])
    q_svd = final_svd.transform(q_vec)

    if final_normalizer is not None:
        q_svd = final_normalizer.transform(q_svd)

    distances, indices = final_knn.kneighbors(q_svd)

    knn_scores = 1 / (1 + distances[0])

    bm25_scores = np.array(bm25.get_scores(query.lower().split()))

    if bm25_scores.max() > 0:
        bm25_scores = bm25_scores / bm25_scores.max()

    candidate_scores = {}

    for knn_score, idx in zip(knn_scores, indices[0]):

        pdf_name = chunk_sources[idx]
        bm25_score = bm25_scores[idx]

        final_score = (hybrid_weight * knn_score) + ((1 - hybrid_weight) * bm25_score)

        if pdf_name not in candidate_scores or final_score > candidate_scores[pdf_name]:
            candidate_scores[pdf_name] = final_score

    ranked_results = sorted(
        candidate_scores.items(),
        key=lambda x: x[1],
        reverse=True
    )

    top5 = [pdf for pdf, score in ranked_results[:5]]
    scores = [score for pdf, score in ranked_results[:5]]

    while len(top5) < 5:
        top5.append("NO_RESULT")

    while len(scores) < 5:
        scores.append(0)

    return top5, scores

# %% [markdown]
# ## Evaluate Final AutoML Retriever
#
# This cell evaluates the final optimized hybrid retrieval system. All evaluation questions are passed through the final retriever, and the retrieved PDFs are compared with the correct answers from the Excel dataset. The cell calculates the final Recall@5, NDCG@5, and p95 latency metrics and compares them with the baseline system.

# %%
correct = 0
ndcg_scores = []
times = []

for _, row in df.iterrows():

    query = row["Question"]
    true_file = row["Correct_PDF"]

    start_time = time.time()

    top5, scores = knn_search_top5(query)

    end_time = time.time()

    times.append(end_time - start_time)

    relevance = [1 if pdf == true_file else 0 for pdf in top5]

    if true_file in top5:
        correct += 1

    ndcg_scores.append(ndcg_score([relevance], [scores]))

final_recall = correct / len(df)
final_ndcg = np.mean(ndcg_scores)
p95_latency = np.percentile(times, 95)
print("Baseline Recall@5:", round(baseline_recall, 4))
print("Baseline NDCG@5:", round(baseline_ndcg, 4))
print("Baseline p95 latency:", round(baseline_p95_latency, 6), "seconds")

print("Final AutoML Recall@5:", round(final_recall, 4))
print("Final AutoML NDCG@5:", round(final_ndcg, 4))
print("Final AutoML p95 latency:", round(p95_latency, 6), "seconds")
# Out:
# Baseline Recall@5: 0.9667
# Baseline NDCG@5: 0.9294
# Baseline p95 latency: 0.001481 seconds
# Final AutoML Recall@5: 0.9667
# Final AutoML NDCG@5: 0.9503
# Final AutoML p95 latency: 0.008843 seconds

# %% [markdown]
# ##  Online Adaptive Hybrid Weight Learning
#
# This cell implements the online learning component using River and ADWIN. For each incoming query, the system retrieves results, evaluates retrieval success, updates the adaptive hybrid retrieval weight based on feedback, and tracks performance over time. The cell also monitors the retrieval stream using ADWIN drift detection to identify changes in retrieval behavior.

# %%
from river import linear_model, preprocessing
from river.drift import ADWIN

online_model = preprocessing.StandardScaler() | linear_model.LogisticRegression()
adwin = ADWIN(delta=0.002)

adaptive_hybrid_weight = float(best["hybrid_weight"])

WEIGHT_STEP = 0.05
MIN_WEIGHT = 0.20
MAX_WEIGHT = 0.80
WINDOW_SIZE = 10

online_successes = 0
online_scores = []
adaptive_weights = []
drift_events = []
online_records = []

error_window = []
smoothed_errors = []

print("Running online learning with smoothed ADWIN error...\n")

for i, row in df.iterrows():

    query = row["Question"]
    true_file = row["Correct_PDF"]

    top5, scores = knn_search_top5(query, hybrid_weight=adaptive_hybrid_weight)

    clicked_helpful = 1 if true_file in top5 else 0

    online_successes += clicked_helpful
    current_prequential_recall = online_successes / (i + 1)

    x = {
        "current_hybrid_weight": float(adaptive_hybrid_weight),
        "top_score": float(scores[0]) if len(scores) > 0 else 0.0,
        "second_score": float(scores[1]) if len(scores) > 1 else 0.0,
        "score_gap": float(scores[0] - scores[1]) if len(scores) > 1 else 0.0,
        "mean_score": float(np.mean(scores)) if len(scores) > 0 else 0.0,
        "std_score": float(np.std(scores)) if len(scores) > 0 else 0.0,
        "question_length": len(query),
        "question_words": len(query.split())
    }

    predicted_helpful = online_model.predict_one(x)

    if predicted_helpful is None:
        predicted_helpful = 0

    helpful_probability = online_model.predict_proba_one(x).get(1, 0.5)

    retrieval_error = 1 - clicked_helpful

    error_window.append(retrieval_error)

    if len(error_window) > WINDOW_SIZE:
        error_window.pop(0)

    smoothed_retrieval_error = float(np.mean(error_window))
    smoothed_errors.append(smoothed_retrieval_error)

    adwin.update(smoothed_retrieval_error)

    drift_detected_now = False
    drift_response = "No reset needed"

    if adwin.drift_detected:
        drift_detected_now = True
        drift_events.append(i)
        drift_response = "ADWIN drift detected: reset River learner and restore Optuna hybrid weight"

        print(f"ADWIN drift detected at step {i}. Resetting learner and hybrid weight.")

        online_model = preprocessing.StandardScaler() | linear_model.LogisticRegression()
        adaptive_hybrid_weight = float(best["hybrid_weight"])

    online_model.learn_one(x, clicked_helpful)

    old_weight = adaptive_hybrid_weight

    lower_weight = float(np.clip(old_weight - WEIGHT_STEP, MIN_WEIGHT, MAX_WEIGHT))
    upper_weight = float(np.clip(old_weight + WEIGHT_STEP, MIN_WEIGHT, MAX_WEIGHT))

    lower_top5, _ = knn_search_top5(query, hybrid_weight=lower_weight)
    upper_top5, _ = knn_search_top5(query, hybrid_weight=upper_weight)

    lower_success = 1 if true_file in lower_top5 else 0
    upper_success = 1 if true_file in upper_top5 else 0

    if clicked_helpful == 0:
        if upper_success > lower_success:
            adaptive_hybrid_weight = upper_weight
        elif lower_success > upper_success:
            adaptive_hybrid_weight = lower_weight
        else:
            adaptive_hybrid_weight = lower_weight
    else:
        adaptive_hybrid_weight = old_weight

    adaptive_hybrid_weight = float(np.clip(adaptive_hybrid_weight, MIN_WEIGHT, MAX_WEIGHT))

    online_scores.append(current_prequential_recall)
    adaptive_weights.append(adaptive_hybrid_weight)

    online_records.append({
        "step": i,
        "query": query,
        "true_pdf": true_file,
        "top5": top5,
        "clicked_helpful": clicked_helpful,
        "predicted_helpful": predicted_helpful,
        "helpful_probability": helpful_probability,
        "retrieval_error": retrieval_error,
        "smoothed_retrieval_error": smoothed_retrieval_error,
        "prequential_recall_at_5": current_prequential_recall,
        "old_hybrid_weight": old_weight,
        "new_hybrid_weight": adaptive_hybrid_weight,
        "drift_detected": drift_detected_now,
        "drift_response": drift_response
    })

online_results_df = pd.DataFrame(online_records)

print("Online learning completed.")
print("Initial adaptive hybrid weight:", round(online_results_df["old_hybrid_weight"].iloc[0], 4))
print("Final adaptive hybrid weight:", round(online_results_df["new_hybrid_weight"].iloc[-1], 4))
print("Initial prequential Recall@5:", round(online_results_df["prequential_recall_at_5"].iloc[0], 4))
print("Final prequential Recall@5:", round(online_results_df["prequential_recall_at_5"].iloc[-1], 4))
print("Natural drift events:", drift_events)

online_results_df
# Out:
# Running online learning with smoothed ADWIN error...
#
# Online learning completed.
# Initial adaptive hybrid weight: 0.703
# Final adaptive hybrid weight: 0.403
# Initial prequential Recall@5: 1.0
# Final prequential Recall@5: 0.96
# Natural drift events: []
#      step                                              query  \
# 0       0  What is the main AI-related objective of Effic...
# 1       1  What is the main AI-related objective of Playi...
# 2       2  What is the main AI-related objective of ADAM:...
# 3       3  What is the main AI-related objective of MLlib...
# 4       4  What is the main AI-related objective of All e...
# ..    ...                                                ...
# 145   145  What data or input is used by the AI method in...
# 146   146  What AI method or model is discussed in Dual-t...
# 147   147  What data or input is used by the AI method in...
# 148   148  What result or improvement is reported for the...
# 149   149  What result or improvement is reported for the...
#
#              true_pdf                                               top5  \
# 0     1301.3781v3.pdf  [1301.3781v3.pdf, D14-1162.pdf, 1806.09055v2.p...
# 1     1312.5602v1.pdf  [1312.5602v1.pdf, 1709.05067v1.pdf, 1711.09883...
# 2     1412.6980v9.pdf  [1412.6980v9.pdf, 1802.07228v2.pdf, 1602.05629...
# 3          15-237.pdf  [15-237.pdf, Zaharia.pdf, 1606.06565v2.pdf, 19...
# 4    1508.07906v2.pdf  [1808.00177v5.pdf, 1606.06565v2.pdf, 1412.6980...
# ..                ...                                                ...
# 145       20-1380.pdf  [20-1380.pdf, 2005.06239v2.pdf, 1602.05629v4.p...
# 146  2005.04353v1.pdf  [2005.04353v1.pdf, NIPS-2012-on-triangular-ver...
# 147  2005.06239v2.pdf  [2005.06239v2.pdf, 1910.10045v2.pdf, 2210.0765...
# 148  2005.11401v4.pdf  [2005.11401v4.pdf, 2310.11511v1.pdf, 2212.0807...
# 149  2006.11239v2.pdf  [2006.11239v2.pdf, 2112.10752v2.pdf, 2205.1148...
#
#      clicked_helpful  predicted_helpful  helpful_probability  retrieval_error  \
# 0                  1              False             0.500000                0
# 1                  1               True             0.501250                0
# 2                  1              False             0.494893                0
# 3                  1              False             0.486606                0
# 4                  0              False             0.483140                1
# ..               ...                ...                  ...              ...
# 145                1               True             0.820082                0
# 146                1               True             0.835867                0
# 147                1               True             0.759769                0
# 148                1               True             0.751363                0
# 149                1               True             0.846395                0
#
#      smoothed_retrieval_error  prequential_recall_at_5  old_hybrid_weight  \
# 0                         0.0                 1.000000           0.702997
# 1                         0.0                 1.000000           0.702997
# 2                         0.0                 1.000000           0.702997
# 3                         0.0                 1.000000           0.702997
# 4                         0.2                 0.800000           0.702997
# ..                        ...                      ...                ...
# 145                       0.0                 0.958904           0.402997
# 146                       0.0                 0.959184           0.402997
# 147                       0.0                 0.959459           0.402997
# 148                       0.0                 0.959732           0.402997
# 149                       0.0                 0.960000           0.402997
#
#      new_hybrid_weight  drift_detected   drift_response
# 0             0.702997           False  No reset needed
# 1             0.702997           False  No reset needed
# 2             0.702997           False  No reset needed
# 3             0.702997           False  No reset needed
# 4             0.652997           False  No reset needed
# ..                 ...             ...              ...
# 145           0.402997           False  No reset needed
# 146           0.402997           False  No reset needed
# 147           0.402997           False  No reset needed
# 148           0.402997           False  No reset needed
# 149           0.402997           False  No reset needed
#
# [150 rows x 14 columns]

# %% [markdown]
# ## ADWIN Drift Stress Test on Query Stream
#
# This cell performs a controlled drift stress test to verify that ADWIN can detect retrieval drift correctly. Artificial drift is injected into the query performance stream, and the modified performance values are monitored by ADWIN. The cell records and prints the detected drift events as evidence of successful drift handling.

# %%
from river import linear_model, preprocessing
from river.drift import ADWIN

DRIFT_POINT = max(30, int(len(df) * 0.45))

stress_model = preprocessing.StandardScaler() | linear_model.LogisticRegression()
stress_adwin = ADWIN(delta=0.002)
stress_hybrid_weight = float(best["hybrid_weight"])

stress_drift_events = []
stress_error_stream = []
stress_smoothed_error_stream = []
stress_preq_recall = []
stress_records = []
stress_successes = 0
stress_error_window = []

WINDOW_SIZE = 10

print("Running ADWIN drift stress test on the actual query stream...\n")
print("Drift injected at step:", DRIFT_POINT)

for i, row in df.iterrows():
    query = row["Question"]
    true_file = row["Correct_PDF"]

    top5, scores = knn_search_top5(query, hybrid_weight=stress_hybrid_weight)
    real_helpful = 1 if true_file in top5 else 0

    if i < DRIFT_POINT:
        feedback_helpful = real_helpful
    else:
        feedback_helpful = 0

    stress_successes += feedback_helpful
    current_stress_recall = stress_successes / (i + 1)

    retrieval_error = 1 - feedback_helpful
    stress_error_stream.append(retrieval_error)

    stress_error_window.append(retrieval_error)
    if len(stress_error_window) > WINDOW_SIZE:
        stress_error_window.pop(0)

    smoothed_error = float(np.mean(stress_error_window))
    stress_smoothed_error_stream.append(smoothed_error)
    stress_preq_recall.append(current_stress_recall)

    stress_adwin.update(smoothed_error)

    drift_detected_now = False
    drift_response = "No reset needed"

    if stress_adwin.drift_detected:
        drift_detected_now = True
        stress_drift_events.append(i)
        drift_response = "ADWIN drift detected: reset River learner and restore Optuna hybrid weight"

        print(f"ADWIN drift detected at step {i}. Resetting learner and hybrid weight.")

        stress_model = preprocessing.StandardScaler() | linear_model.LogisticRegression()
        stress_hybrid_weight = float(best["hybrid_weight"])

    x = {
        "current_hybrid_weight": float(stress_hybrid_weight),
        "top_score": float(scores[0]) if len(scores) > 0 else 0.0,
        "second_score": float(scores[1]) if len(scores) > 1 else 0.0,
        "score_gap": float(scores[0] - scores[1]) if len(scores) > 1 else 0.0,
        "mean_score": float(np.mean(scores)) if len(scores) > 0 else 0.0,
        "std_score": float(np.std(scores)) if len(scores) > 0 else 0.0,
        "question_length": len(query),
        "question_words": len(query.split())
    }

    stress_model.learn_one(x, feedback_helpful)

    old_weight = stress_hybrid_weight

    if feedback_helpful == 0:
        stress_hybrid_weight = float(np.clip(stress_hybrid_weight - 0.05, MIN_WEIGHT, MAX_WEIGHT))
    else:
        stress_hybrid_weight = float(np.clip(stress_hybrid_weight + 0.01, MIN_WEIGHT, MAX_WEIGHT))

    stress_records.append({
        "step": i,
        "query": query,
        "true_pdf": true_file,
        "real_retrieval_helpful": real_helpful,
        "feedback_after_drift_injection": feedback_helpful,
        "raw_retrieval_error": retrieval_error,
        "smoothed_retrieval_error": smoothed_error,
        "prequential_recall_at_5_under_drift": current_stress_recall,
        "old_hybrid_weight": old_weight,
        "new_hybrid_weight": stress_hybrid_weight,
        "drift_detected": drift_detected_now,
        "drift_response": drift_response
    })

stress_drift_df = pd.DataFrame(stress_records)

print("\nADWIN Drift Stress-Test Summary")
print("Natural/normal online drift events from main run:", drift_events)
print("Stress-test drift events:", stress_drift_events)
print("Number of stress-test drift events:", len(stress_drift_events))

stress_drift_df
# Out:
# Running ADWIN drift stress test on the actual query stream...
#
# Drift injected at step: 67
# ADWIN drift detected at step 95. Resetting learner and hybrid weight.
#
# ADWIN Drift Stress-Test Summary
# Natural/normal online drift events from main run: []
# Stress-test drift events: [95]
# Number of stress-test drift events: 1
#      step                                              query  \
# 0       0  What is the main AI-related objective of Effic...
# 1       1  What is the main AI-related objective of Playi...
# 2       2  What is the main AI-related objective of ADAM:...
# 3       3  What is the main AI-related objective of MLlib...
# 4       4  What is the main AI-related objective of All e...
# ..    ...                                                ...
# 145   145  What data or input is used by the AI method in...
# 146   146  What AI method or model is discussed in Dual-t...
# 147   147  What data or input is used by the AI method in...
# 148   148  What result or improvement is reported for the...
# 149   149  What result or improvement is reported for the...
#
#              true_pdf  real_retrieval_helpful  feedback_after_drift_injection  \
# 0     1301.3781v3.pdf                       1                               1
# 1     1312.5602v1.pdf                       1                               1
# 2     1412.6980v9.pdf                       1                               1
# 3          15-237.pdf                       1                               1
# 4    1508.07906v2.pdf                       0                               0
# ..                ...                     ...                             ...
# 145       20-1380.pdf                       1                               0
# 146  2005.04353v1.pdf                       1                               0
# 147  2005.06239v2.pdf                       1                               0
# 148  2005.11401v4.pdf                       1                               0
# 149  2006.11239v2.pdf                       1                               0
#
#      raw_retrieval_error  smoothed_retrieval_error  \
# 0                      0                       0.0
# 1                      0                       0.0
# 2                      0                       0.0
# 3                      0                       0.0
# 4                      1                       0.2
# ..                   ...                       ...
# 145                    1                       1.0
# 146                    1                       1.0
# 147                    1                       1.0
# 148                    1                       1.0
# 149                    1                       1.0
#
#      prequential_recall_at_5_under_drift  old_hybrid_weight  \
# 0                               1.000000           0.702997
# 1                               1.000000           0.712997
# 2                               1.000000           0.722997
# 3                               1.000000           0.732997
# 4                               0.800000           0.742997
# ..                                   ...                ...
# 145                             0.445205           0.200000
# 146                             0.442177           0.200000
# 147                             0.439189           0.200000
# 148                             0.436242           0.200000
# 149                             0.433333           0.200000
#
#      new_hybrid_weight  drift_detected   drift_response
# 0             0.712997           False  No reset needed
# 1             0.722997           False  No reset needed
# 2             0.732997           False  No reset needed
# 3             0.742997           False  No reset needed
# 4             0.692997           False  No reset needed
# ..                 ...             ...              ...
# 145           0.200000           False  No reset needed
# 146           0.200000           False  No reset needed
# 147           0.200000           False  No reset needed
# 148           0.200000           False  No reset needed
# 149           0.200000           False  No reset needed
#
# [150 rows x 12 columns]

# %% [markdown]
# ## Plot Online Learning Performance
#
# This cell visualizes the online learning process using graphs and plots. It shows how the prequential Recall@5 performance changes over time and how the adaptive hybrid retrieval weight evolves after feedback updates. These plots provide evidence that the retrieval system learns and adapts continuously during streaming evaluation.
#
# ## Plot ADWIN Drift Evidence
#
# This cell also creates a visual representation of the drift stress test results. It plots the performance stream, highlights where drift was injected, and marks where ADWIN successfully detected the drift. This graph demonstrates that the online learning system can recognize and respond to changes in retrieval performance.

# %%
# Prequential Recall@5 (Main Online Learning)
plt.figure(figsize=(10, 6))
plt.plot(range(0, len(online_scores)), online_scores, marker='o', linewidth=2, markersize=3, color='blue')
plt.xlabel('Online Step', fontsize=12)
plt.ylabel('Prequential Recall@5', fontsize=12)
plt.title('Online Adaptive Hybrid Weight: Prequential Recall@5', fontsize=14)
plt.ylim(0.70, 1.05)
plt.grid(True, alpha=0.3)
plt.axhline(y=online_scores[-1], linestyle='--', color='gray', alpha=0.5, label=f'Final: {online_scores[-1]:.3f}')
plt.legend()
plt.tight_layout()
plt.savefig('prequential_recall_at5_plot.png', dpi=300, bbox_inches='tight')
plt.show()
print("Saved: prequential_recall_at5_plot.png")

# Adaptive Hybrid Weight Evolution
plt.figure(figsize=(10, 6))
plt.plot(range(0, len(adaptive_weights)), adaptive_weights, marker='s', linewidth=2, markersize=3, color='green')
plt.xlabel('Online Step', fontsize=12)
plt.ylabel('Adaptive Hybrid Weight', fontsize=12)
plt.title('Adaptive Hybrid Weight Updated from Feedback', fontsize=14)
plt.ylim(0.40, 0.70)
plt.grid(True, alpha=0.3)
plt.axhline(y=adaptive_weights[0], linestyle='--', color='gray', alpha=0.5, label=f'Initial: {adaptive_weights[0]:.3f}')
plt.axhline(y=adaptive_weights[-1], linestyle='--', color='red', alpha=0.5, label=f'Final: {adaptive_weights[-1]:.3f}')
plt.legend()
plt.tight_layout()
plt.savefig('adaptive_hybrid_weight_plot.png', dpi=300, bbox_inches='tight')
plt.show()
print("Saved: adaptive_hybrid_weight_plot.png")

# ADWIN Drift Evidence (Stress Test - Smoothed Error Stream)
# IMPORTANT: Run the ADWIN stress-test cell before this plot cell.
plt.figure(figsize=(10, 6))

steps = range(1, len(stress_smoothed_error_stream) + 1)

plt.plot(
    steps,
    stress_smoothed_error_stream,
    linewidth=2,
    label="Stress-Test Smoothed Retrieval Error"
)

plt.axvline(
    DRIFT_POINT + 1,
    linestyle=":",
    linewidth=2,
    label=f"Injected drift point: step {DRIFT_POINT + 1}"
)

for drift_step in stress_drift_events:
    plt.axvline(
        drift_step + 1,
        linestyle="--",
        linewidth=2,
        label=f"ADWIN detected drift: step {drift_step + 1}"
    )

plt.xlabel("Online Step")
plt.ylabel("Smoothed Retrieval Error")
plt.title("ADWIN Drift Response Evidence on Stress-Test Query Stream")
plt.ylim(-0.05, 1.05)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.savefig("adwin_actual_query_stream_drift_evidence.png", dpi=300, bbox_inches="tight")
plt.show()
print("Saved: adwin_actual_query_stream_drift_evidence.png")

# Prequential Recall Under Drift Stress Test
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(stress_preq_recall) + 1), stress_preq_recall, marker='o', linewidth=2, markersize=3, color='purple')
plt.axvline(DRIFT_POINT + 1, linestyle=':', color='orange', linewidth=2, label=f'Injected drift point (step {DRIFT_POINT + 1})')

for drift_step in stress_drift_events:
    plt.axvline(drift_step + 1, linestyle='--', color='red', linewidth=2, label=f'ADWIN detected drift at step {drift_step + 1}')

plt.xlabel('Online Step', fontsize=12)
plt.ylabel('Prequential Recall@5', fontsize=12)
plt.title('Prequential Retrieval Performance During Drift Stress Test', fontsize=14)
plt.ylim(0.30, 1.05)
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('prequential_recall_under_drift_stress_test.png', dpi=300, bbox_inches='tight')
plt.show()
print("Saved: prequential_recall_under_drift_stress_test.png")
print(f"   - Initial recall: {stress_preq_recall[0]:.4f}")
print(f"   - Final recall after drift: {stress_preq_recall[-1]:.4f}")
# Out:
# Saved: prequential_recall_at5_plot.png
# Saved: adaptive_hybrid_weight_plot.png
# Saved: adwin_actual_query_stream_drift_evidence.png
# Saved: prequential_recall_under_drift_stress_test.png
#    - Initial recall: 1.0000
#    - Final recall after drift: 0.4333

# %% [markdown]
# ## Save Final Run Card
#
# This cell saves the final project configuration and evaluation results into a JSON run card file. The run card contains the best AutoML parameters, baseline metrics, final optimized metrics, online learning results, and drift detection evidence. Saving the run card improves reproducibility and documents the final system configuration.

# %%
import json
import os
import numpy as np

assert "online_results_df" in globals(), "Run the online learning cell first. online_results_df is missing."
assert "stress_drift_df" in globals(), "Run the ADWIN stress-test cell before this run-card cell. stress_drift_df is missing."
assert "sampler_results_df" in globals(), "Run the AutoML optimizer comparison cell first. sampler_results_df is missing."
assert "study" in globals(), "Run the AutoML optimizer comparison cell first. study is missing."
assert "best" in globals(), "Run the AutoML optimizer comparison cell first. best is missing."


def json_safe(value):
    if isinstance(value, dict):
        return {str(k): json_safe(v) for k, v in value.items()}
    if isinstance(value, list):
        return [json_safe(v) for v in value]
    if isinstance(value, tuple):
        return [json_safe(v) for v in value]
    if isinstance(value, (np.integer,)):
        return int(value)
    if isinstance(value, (np.floating,)):
        return float(value)
    if isinstance(value, (np.bool_,)):
        return bool(value)
    return value

final_adaptive_weight = round(float(online_results_df["new_hybrid_weight"].iloc[-1]), 4)
initial_adaptive_weight = round(float(online_results_df["old_hybrid_weight"].iloc[0]), 4)

final_preq_recall = round(float(online_results_df["prequential_recall_at_5"].iloc[-1]), 4)
initial_preq_recall = round(float(online_results_df["prequential_recall_at_5"].iloc[0]), 4)

optimizer_comparison = {}
for optimizer_name, row in sampler_results_df.iterrows():
    optimizer_comparison[optimizer_name] = {
        "best_objective": round(float(row["best_objective"]), 4),
        "best_params": json_safe(row["best_params"]),
        "recall_at_5": round(float(row["recall_at_5"]), 4),
        "ndcg_at_5": round(float(row["ndcg_at_5"]), 4),
        "p95_latency_seconds": round(float(row["p95_latency"]), 6)
    }

stress_detected = len(stress_drift_events) > 0
stress_detection_plot_step = int(stress_drift_events[0] + 1) if stress_detected else None

run_card = {
    "track": "A - Supervised auto-tuned kNN retriever",
    "dataset": "109 AI-related PDFs",
    "num_questions": int(len(df)),
    "num_chunks": int(len(chunk_texts)),
    "extraction_mode": "title + abstract only",
    "automl_tool": "Optuna",

    "optimizer_comparison": optimizer_comparison,
    "selected_optimizer": str(best_sampler_name) if "best_sampler_name" in globals() else "Selected from optimizer comparison",

    "baseline_recall_at_5": round(float(baseline_recall), 4),
    "baseline_ndcg_at_5": round(float(baseline_ndcg), 4),
    "baseline_p95_latency_seconds": round(float(baseline_p95_latency), 6),

    "final_recall_at_5": round(float(study.best_trial.user_attrs["recall_at_5"]), 4),
    "final_ndcg_at_5": round(float(study.best_trial.user_attrs["ndcg_at_5"]), 4),
    "final_p95_latency_seconds": round(float(study.best_trial.user_attrs["p95_latency"]), 6),

    "best_params": json_safe(best),
    "best_objective_score": round(float(study.best_value), 4),

    "online_learning": {
        "tool": "River",
        "model": "StandardScaler + LogisticRegression",
        "task": "Adaptive hybrid fusion weight from feedback",

        "initial_hybrid_weight": initial_adaptive_weight,
        "final_adaptive_hybrid_weight": final_adaptive_weight,

        "prequential_initial_recall_at_5": initial_preq_recall,
        "prequential_final_recall_at_5": final_preq_recall,

        "natural_stream_drift_events_zero_indexed": [int(x) for x in drift_events],
        "natural_stream_drift_detected": bool(len(drift_events) > 0),

        "stress_test_drift_injection_zero_indexed": int(DRIFT_POINT),
        "stress_test_drift_events_zero_indexed": [int(x) for x in stress_drift_events],
        "stress_test_drift_detected_plot_step": stress_detection_plot_step,
        "stress_test_drift_detected": bool(stress_detected)
    },

    "plots": {
        "prequential_recall_plot": "prequential_recall_at5_plot.png",
        "adaptive_weight_plot": "adaptive_hybrid_weight_plot.png",
        "adwin_error_plot": "adwin_actual_query_stream_drift_evidence.png",
        "drift_stress_recall_plot": "prequential_recall_under_drift_stress_test.png"
    }
}

run_card = json_safe(run_card)

with open("run_card_corrected_final.json", "w") as f:
    json.dump(run_card, f, indent=4)

print("Saved run_card_corrected_final.json")
print("Selected optimizer:", run_card["selected_optimizer"])
print("Best params:", run_card["best_params"])
print("Best objective score:", run_card["best_objective_score"])
print("Final Recall@5:", run_card["final_recall_at_5"])
print("Final NDCG@5:", run_card["final_ndcg_at_5"])
print("Final p95 latency:", run_card["final_p95_latency_seconds"])
print("Natural drift events:", run_card["online_learning"]["natural_stream_drift_events_zero_indexed"])
print("Stress drift events:", run_card["online_learning"]["stress_test_drift_events_zero_indexed"])
print("File location:", os.path.abspath("run_card_corrected_final.json"))
# Out:
# Saved run_card_corrected_final.json
# Selected optimizer: Random Search
# Best params: {'k': 20, 'metric': 'cosine', 'svd_dim': 200, 'normalize': False, 'max_features': 5000, 'hybrid_weight': 0.7029972228266828}
# Best objective score: 0.9581
# Final Recall@5: 0.9667
# Final NDCG@5: 0.9503
# Final p95 latency: 0.007339
# Natural drift events: []
# Stress drift events: [95]
# File location: /content/run_card_corrected_final.json
